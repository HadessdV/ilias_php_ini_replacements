# %%
settings_names = {
    'max_execution_time': '600',
    'max_input_vars': '10000',
    'memory_limit': '512M',
    'post_max_size': '512M',
    'upload_max_filesize:': '512M',
    'error_reporting': 'E_ALL & ~E_DEPRECATED & ~E_STRICT & ~E_NOTICE',
    'display_errors': 'On',
    'session.gc_probability' : '1',
    'session.gc_divisor' : '100',
    'session.gc_maxlifetime' : '14400',
    'session.hash_function' : '0',
    'session.cookie_httponly' : 'On',
    'session.save_handler' : 'files',
    'session.cookie_secure' : 'On',
    'allow_url_fopen': 'On', 
    'opcache.enable':'1',
    'opcache.enable_cli':'1',
    'opcache.interned_strings_buffer':'8',
    'opcache.max_accelerated_files':'10000',
    'opcache.memory_consumption':'128',
    'opcache.save_comments':'1',
    'opcache.revalidate_freq':'1',
}

apc_names = {
    'apc.enabled':'1',
    'apc.shm_size':'256M',
    'apc.ttl':'7200',
    'apc.enable_cli':'1',
    'apc.gc_ttl':'3600',
    'apc.entries_hint':'4096',
    'apc.slam_defense':'1',
    'apc.serializer':'igbinary',
}

def replace_php_setting(line: str) -> str : 
    for key in settings_names:
        if key in line:
                return line

# %%
counter = 0
with open('php.ini', 'r') as file:
    file_data = file.readlines()
    for line in file_data:
        key = replace_php_setting(line)
        if key:
            counter += 1
            print(str(counter) + ": " + key)
# Out:
# 1: ; display_errors
#
# 2: ; error_reporting
#
# 3: ; session.gc_divisor
#
# 4: max_execution_time = 30
#
# 5: ;max_input_vars = 1000
#
# 6: memory_limit = 128M
#
# 7: error_reporting = E_ALL & ~E_DEPRECATED & ~E_STRICT
#
# 8: display_errors = Off
#
# 9: ; separately from display_errors. PHP's default behavior is to suppress those
#
# 10: post_max_size = 8M
#
# 11: allow_url_fopen = On
#
# 12: session.save_handler = files
#
# 13: ;session.cookie_secure =
#
# 14: session.cookie_httponly =
#
# 15: session.gc_probability = 0
#
# 16: session.gc_divisor = 1000
#
# 17: session.gc_maxlifetime = 1440
#
# 18: ;       session.gc_maxlifetime to 1440 (1440 seconds = 24 minutes):
#
# 19: ; Eval the expression with current error_reporting().  Set to true if you want
#
# 20: ; error_reporting(0) around the eval().
#
# 21: ;opcache.enable=1
#
# 22: ;opcache.enable_cli=0
#
# 23: ;opcache.memory_consumption=128
#
# 24: ;opcache.interned_strings_buffer=8
#
# 25: ;opcache.max_accelerated_files=10000
#
# 26: ;opcache.revalidate_freq=2
#
# 27: ;opcache.save_comments=1
#
# 28: ;opcache.enable_file_override=0
